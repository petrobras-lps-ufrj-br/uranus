# %% [markdown]
# # How to Donwload Cognite Database?

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import atlas_mpl_style as ampl
import os, warnings
import matplotlib

from loguru import logger
from ai.clients import Cognite
from datetime import datetime

ampl.use_atlas_style()
plt.rcParams['font.family'] = 'DeJavu Sans'
plt.rcParams['font.serif'] = ['Times New Roman']
warnings.filterwarnings("ignore")
matplotlib.use('Agg')

# %% [markdown]
# ## How to connect?

# %%
CLIENT_SECRET = "olz8Q~.m0ldyXULnMnry_NiWhb~2FDmgWYzeBcKZ" # this came from CDF token generation page
TENANT_ID     = "48d5043c-cf70-4c49-881c-c638f5796997" # this is the dataset project id
client        = Cognite("compressor", client_secret=CLIENT_SECRET, tenant_id=TENANT_ID)
# Out:
# 2026-01-03 21:35:42.508 | INFO     | shield.clients.cognite:__init__:71 - publicdatacdm

# %%
start_time = datetime(2019, 9, 1) # Tempo disponível no dataset (6 meses)
end_time = datetime(2020, 3, 1)
df, info = client.get_dataframe( '23-KA-9101', start_time, end_time )
# Out:
# 2026-01-03 21:35:42.998 | INFO     | shield.clients.cognite:get_dataframe:121 - Searching data from 2019-09-01 00:00:00 to 2020-03-01 00:00:00 for asset '23-KA-9101'
# {'pi:160217': 'PH (CBM) 1st Stage ActCompr Poly Eff',
#  'pi:160218': 'PH (CBM) 1st Stg ActCompr Poly Head',
#  'pi:160219': 'PH (CBM) 1st Stage ActPress Ratio',
#  'pi:160220': 'PH (CBM) 1st Stage ActShaft Power',
#  'pi:160221': 'PH (CBM) 1st Stage ExpCompr Poly Eff',
#  'pi:160222': 'PH (CBM) 1st Stg ExpCompr Poly Head',
#  'pi:160223': 'PH (CBM) 1st Stage ExpPress Ratio',
#  'pi:160224': 'PH (CBM) 1st Stage ExpShaft Power',
#  'pi:160225': 'PH (CBM) 1st Stage Poly Eff Dev',
#  'pi:160226': 'PH (CBM) 1st Stage Poly Head Dev',
#  'pi:160227': 'PH (CBM) 1st Stage Press Rat Dev',
#  'pi:160228': 'PH (CBM) 1st Stage Shft Pwr Dev'}

# %%
df.tail()
# Out:
#                      PH (CBM) 1st Stage ExpPress Ratio  \
# 2020-03-01 02:57:52                           2.873428
# 2020-03-01 02:58:22                           2.789148
# 2020-03-01 02:58:52                           3.102035
# 2020-03-01 02:59:22                           3.232144
# 2020-03-01 02:59:52                           3.198250
#
#                      PH (CBM) 1st Stage Poly Head Dev  \
# 2020-03-01 02:57:52                         21.737337
# 2020-03-01 02:58:22                         23.996879
# 2020-03-01 02:58:52                          9.302431
# 2020-03-01 02:59:22                          5.882710
# 2020-03-01 02:59:52                          8.702010
#
#                      PH (CBM) 1st Stage ActShaft Power  \
# 2020-03-01 02:57:52                        9581.932694
# 2020-03-01 02:58:22                       10360.703495
# 2020-03-01 02:58:52                        9850.780832
# 2020-03-01 02:59:22                        9144.089359
# ...

# %%
info.head()
# Out:
#   external_id                      name  is_string  \
# 0   pi:160223  VAL_23-KA-9101_EPR:VALUE      False
# 1   pi:160226  VAL_23-KA-9101_PHD:VALUE      False
# 2   pi:160220  VAL_23-KA-9101_ASP:VALUE      False
# 3   pi:160227  VAL_23-KA-9101_PRD:VALUE      False
# 4   pi:160218  VAL_23-KA-9101_APH:VALUE      False
#
#                                             metadata          asset_id  \
# 0  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 1  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 2  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 3  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 4  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
#
#    is_step                          description security_categories  \
# 0    False    PH (CBM) 1st Stage ExpPress Ratio                  []
# 1    False     PH (CBM) 1st Stage Poly Head Dev                  []
# ...

# %%
df.shape
# Out:
# (547508, 12)

# %%
#df.to_csv("compressor.csv")

# %% [markdown]
# ## Explore data:
